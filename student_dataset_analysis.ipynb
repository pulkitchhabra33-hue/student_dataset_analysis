# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv(r"C:\Users\pulki\Student_performance_data _.csv")
df.index= range(1, len(df)+1)
df
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 1          1001   17       1          0                  2        19.833723
# 2          1002   18       0          0                  1        15.408756
# 3          1003   15       0          2                  3         4.210570
# 4          1004   17       1          0                  3        10.028829
# 5          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2388       3388   18       1          0                  3        10.680555
# 2389       3389   17       0          0                  1         7.583217
# 2390       3390   16       1          0                  2         6.805500
# 2391       3391   16       1          1                  0        12.416653
# 2392       3392   16       1          0                  2        17.819907
#
# ...

# %%
df.head(20)
# Out:
#     StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 1        1001   17       1          0                  2        19.833723
# 2        1002   18       0          0                  1        15.408756
# 3        1003   15       0          2                  3         4.210570
# 4        1004   17       1          0                  3        10.028829
# 5        1005   17       1          0                  2         4.672495
# 6        1006   18       0          0                  1         8.191219
# 7        1007   15       0          1                  1        15.601680
# 8        1008   15       1          1                  4        15.424496
# 9        1009   17       0          0                  0         4.562008
# 10       1010   16       1          0                  1        18.444466
# 11       1011   17       0          0                  1        11.851364
# 12       1012   17       0          0                  1         7.598486
# ...

# %%
df.tail(20)
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 2373       3373   18       0          1                  2         9.404982
# 2374       3374   18       0          3                  2        19.088954
# 2375       3375   16       0          2                  1         2.313504
# 2376       3376   18       0          0                  2        18.925290
# 2377       3377   17       1          2                  2        14.667230
# 2378       3378   18       0          0                  2        12.749976
# 2379       3379   15       1          0                  2        12.905555
# 2380       3380   18       1          0                  2        16.534553
# 2381       3381   16       1          0                  2         2.138397
# 2382       3382   15       0          2                  0        10.095086
# 2383       3383   16       0          0                  3        13.941823
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 1 to 2392
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StudentID          2392 non-null   int64
#  1   Age                2392 non-null   int64
#  2   Gender             2392 non-null   int64
#  3   Ethnicity          2392 non-null   int64
#  4   ParentalEducation  2392 non-null   int64
#  5   StudyTimeWeekly    2392 non-null   float64
#  6   Absences           2392 non-null   int64
#  7   Tutoring           2392 non-null   int64
#  8   ParentalSupport    2392 non-null   int64
#  9   Extracurricular    2392 non-null   int64
#  10  Sports             2392 non-null   int64
#  11  Music              2392 non-null   int64
#  12  Volunteering       2392 non-null   int64
#  13  GPA                2392 non-null   float64
#  14  GradeClass         2392 non-null   float64
# dtypes: float64(3), int64(12)
# memory usage: 280.4 KB

# %%
df.describe()
# Out:
#          StudentID          Age       Gender    Ethnicity  ParentalEducation  \
# count  2392.000000  2392.000000  2392.000000  2392.000000        2392.000000
# mean   2196.500000    16.468645     0.510870     0.877508           1.746237
# std     690.655244     1.123798     0.499986     1.028476           1.000411
# min    1001.000000    15.000000     0.000000     0.000000           0.000000
# 25%    1598.750000    15.000000     0.000000     0.000000           1.000000
# 50%    2196.500000    16.000000     1.000000     0.000000           2.000000
# 75%    2794.250000    17.000000     1.000000     2.000000           2.000000
# max    3392.000000    18.000000     1.000000     3.000000           4.000000
#
#        StudyTimeWeekly     Absences     Tutoring  ParentalSupport  \
# count      2392.000000  2392.000000  2392.000000      2392.000000
# mean          9.771992    14.541388     0.301421         2.122074
# std           5.652774     8.467417     0.458971         1.122813
# ...

# %%
df.isnull().sum()
# Out:
# StudentID            0
# Age                  0
# Gender               0
# Ethnicity            0
# ParentalEducation    0
# StudyTimeWeekly      0
# Absences             0
# Tutoring             0
# ParentalSupport      0
# Extracurricular      0
# Sports               0
# Music                0
# Volunteering         0
# GPA                  0
# GradeClass           0
# dtype: int64

# %%
# Null Values' Heatmap
sns.heatmap(df.isnull(), cbar= False)
plt.show()

# %%
df['GPA'].mean()
# Out:
# np.float64(1.9061863027265407)

# %%
df['GPA'].median()
# Out:
# np.float64(1.8933926937866847)

# %%
df['GPA'].mode()
# Out:
# 0    0.0
# Name: GPA, dtype: float64

# %%
#Number of zeroes in the GPA column of the dataframe
(df['GPA']==0).sum()
# Out:
# np.int64(16)

# %%
sns.boxplot(y= df['GPA'])
plt.show()

# %%
df['Absences'].std()
# Out:
# np.float64(8.467417379917386)

# %%
df['Absences'].var()
# Out:
# np.float64(71.697157085727)

# %%
Absences_range= df['Absences'].max() - df['Absences'].min()
Absences_range
# Out:
# np.int64(29)

# %%
sns.histplot(df['Absences'], kde= True, color= 'orange')
plt.title("Plot of Absences of Students")
plt.show()

# %%
df['GPA'].skew()
# Out:
# np.float64(0.014525601346976225)

# %%
df
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 1          1001   17       1          0                  2        19.833723
# 2          1002   18       0          0                  1        15.408756
# 3          1003   15       0          2                  3         4.210570
# 4          1004   17       1          0                  3        10.028829
# 5          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2388       3388   18       1          0                  3        10.680555
# 2389       3389   17       0          0                  1         7.583217
# 2390       3390   16       1          0                  2         6.805500
# 2391       3391   16       1          1                  0        12.416653
# 2392       3392   16       1          0                  2        17.819907
#
# ...

# %%
#Some Good Plots
sns.barplot(x= 'Gender', y= 'GPA', data= df, color= 'skyblue')
plt.title('Gender vs GPA of Students')
plt.show()

# %%
sns.barplot(x= 'Tutoring', y= 'GPA', data= df, color= 'orange')
plt.title('Tutoring vs GPA of Students')
plt.show()

# %%
sns.barplot(x= 'ParentalSupport', y= 'GPA', data= df, color= 'orange')
plt.title('Parental Support vs GPA of Students')
plt.show()
# Very Low parental support --> 0, 
# Low parental support --> 1, 
# Medium support --> 2,	
# High support --> 3,
# Very High parental support --> 4

# %%
sns.heatmap(df[['Age','StudyTimeWeekly','Absences','GPA']].corr(), annot=True)
plt.show()

# %%
sns.boxplot(x= 'Extracurricular', y= 'Absences', data= df, color= 'red')
plt.title('Extracurricular of Students vs Absences of Students')
plt.show()

# %%
(df['GPA']>3).mean()
# Out:
# np.float64(0.1341973244147157)

# %%
sns.regplot(x= 'StudyTimeWeekly', y= 'GPA', data= df.head(50))
plt.title('Weekly Time Study of Students vs their GPA')
plt.show()

# %%
sns.barplot(x= 'Absences', y= 'GPA', data= df, color= 'pink')
plt.title('Absences of the Students vs their GPA')
plt.xticks(rotation= 90)
plt.show()

# %%
sns.barplot(x= 'ParentalEducation', y= 'GPA', data= df, color= 'orange')
plt.title('Parental Education Data and the Students GPA')
plt.show()
# No formal education / Primary school --> 0,
# Middle school --> 1,
# High school --> 2,
# Bachelor’s degree --> 3,
# Master’s / Professional degree --> 4

# %%
# Average GPA Based on Parental Education Level
df.groupby('ParentalEducation')['GPA'].mean()
# Out:
# ParentalEducation
# 0    1.893045
# 1    1.944022
# 2    1.929881
# 3    1.809082
# 4    1.815812
# Name: GPA, dtype: float64

# %%
sns.countplot(x= 'ParentalEducation', data= df)
plt.title("Parental Education Distribution")
plt.show()

# %%
print(" FINAL CONCLUSION – Student Performance Analysis\n")
print("1. GPA shows a wide spread, with the most common value being 0. Many students have very low GPA.")
print("2. Students with higher study time per week tend to score better in GPA.")
print("3. Higher absences result in significantly lower GPA, showing attendance is strongly linked to performance.")
print("4. Students receiving higher parental support generally have higher GPA and fewer absences.")
print("5. Gender differences are minimal overall, but small trends exist depending on categories.")
print("6. Extracurricular, sports, music, and volunteering show positive impact on GPA for many students.")
print("7. StudyTimeWeekly, GradeClass, and ParentalSupport have positive correlation with GPA.")
print("8. Absences have a clear negative correlation with GPA.")
print()
print("Overall: Academic performance is strongly influenced by study habits, parental involvement, attendance, and extracurricular participation.")
# Out:
#  FINAL CONCLUSION – Student Performance Analysis
#
# 1. GPA shows a wide spread, with the most common value being 0. Many students have very low GPA.
# 2. Students with higher study time per week tend to score better in GPA.
# 3. Higher absences result in significantly lower GPA, showing attendance is strongly linked to performance.
# 4. Students receiving higher parental support generally have higher GPA and fewer absences.
# 5. Gender differences are minimal overall, but small trends exist depending on categories.
# 6. Extracurricular, sports, music, and volunteering show positive impact on GPA for many students.
# 7. StudyTimeWeekly, GradeClass, and ParentalSupport have positive correlation with GPA.
# 8. Absences have a clear negative correlation with GPA.
#
# Overall: Academic performance is strongly influenced by study habits, parental involvement, attendance, and extracurricular participation.
